# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pandas as pd
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/__init__.py:14
#      12 for _dependency in _hard_dependencies:
#      13     try:
# ---> 14         __import__(_dependency)
#      15     except ImportError as _e:  # pragma: no cover
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~/Documents/python/numpy.py:5
#       1 import numpy as np
#       3 # create an array in python using numpy
# ----> 5 a=np.array([1,2])
#
# AttributeError: partially initialized module 'numpy' has no attribute 'array' (most likely due to a circular import)

# %%
# to read the csv files

# %%
# parameters used n reading the csv files

# %%
#sep,header,names

# %%
names = ['age', 'workclass', 'fnlwgt', 'education', 'educationnum', 'maritalstatus', 'occupation', 'relationship', 'race',
        'sex', 'capitalgain', 'capitalloss', 'hoursperweek', 'nativecountry', 'label']

# %%
names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'educationnum',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'nativecountry',
#  'label']

# %%
df=pd.read_csv("/Users/chowdaryadithyasaividivada/Downloads/adult/adult.data",header=None,names=names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df=pd.read_csv("/Users/chowdaryadithyasaividivada/Downloads/adult/adult.data",header=None,names=names)
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
print(df.head())
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry   label
# 0         2174            0            40   United-States   <=50K
# ...

# %%
df
# Out:
#        age          workclass  fnlwgt    education  educationnum  \
# 0       39          State-gov   77516    Bachelors            13
# 1       50   Self-emp-not-inc   83311    Bachelors            13
# 2       38            Private  215646      HS-grad             9
# 3       53            Private  234721         11th             7
# 4       28            Private  338409    Bachelors            13
# ...    ...                ...     ...          ...           ...
# 32556   27            Private  257302   Assoc-acdm            12
# 32557   40            Private  154374      HS-grad             9
# 32558   58            Private  151910      HS-grad             9
# 32559   22            Private  201490      HS-grad             9
# 32560   52       Self-emp-inc  287927      HS-grad             9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
# in csv file the data was separated with the ','

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry   label
# 0         2174            0            40   United-States   <=50K
# ...

# %%
# reading json files using python

# %%
import json

# %%
jsonstring="""{
    "glossary": {
        "title": "example glossary",
        "GlossDiv": {
            "title": "S",
            "GlossList": {
                "GlossEntry": {
                    "ID": "SGML",
                    "SortAs": "SGML",
                    "GlossTerm": "Standard Generalized Markup Language",
                    "Acronym": "SGML",
                    "Abbrev": "ISO 8879:1986",
                    "GlossDef": {
                        "para": "A meta-markup language, used to create markup languages such as DocBook.",
                        "GlossSeeAlso": ["GML", "XML"]
                    },
                    "GlossSee": "markup"
                }
            }
        }
    }
}"""

# %%
jsonstring
# Out:
# '{\n    "glossary": {\n        "title": "example glossary",\n        "GlossDiv": {\n            "title": "S",\n            "GlossList": {\n                "GlossEntry": {\n                    "ID": "SGML",\n                    "SortAs": "SGML",\n                    "GlossTerm": "Standard Generalized Markup Language",\n                    "Acronym": "SGML",\n                    "Abbrev": "ISO 8879:1986",\n                    "GlossDef": {\n                        "para": "A meta-markup language, used to create markup languages such as DocBook.",\n                        "GlossSeeAlso": ["GML", "XML"]\n                    },\n                    "GlossSee": "markup"\n                }\n            }\n        }\n    }\n}'

# %%
jsondata=json.loads(jsonstring)

# %%
jsondata
# Out:
# {'glossary': {'title': 'example glossary',
#   'GlossDiv': {'title': 'S',
#    'GlossList': {'GlossEntry': {'ID': 'SGML',
#      'SortAs': 'SGML',
#      'GlossTerm': 'Standard Generalized Markup Language',
#      'Acronym': 'SGML',
#      'Abbrev': 'ISO 8879:1986',
#      'GlossDef': {'para': 'A meta-markup language, used to create markup languages such as DocBook.',
#       'GlossSeeAlso': ['GML', 'XML']},
#      'GlossSee': 'markup'}}}}}

# %%
# raw files
